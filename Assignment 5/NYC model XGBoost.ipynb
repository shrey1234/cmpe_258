# %%
import numpy as np
import pandas as pd
import xgboost as xgb

import matplotlib.pyplot as plt
import seaborn as sns
% matplotlib inline

plt.style.use('seaborn-whitegrid')

import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train_df = pd.read_csv("/content/drive/MyDrive/258/Assignment 5/train.csv",nrows = 5_000_000)

# %%
train_df.shape
# Out:
# (5000000, 8)

# %%
train_df.describe()
# Out:
#         fare_amount  pickup_longitude  ...  dropoff_latitude  passenger_count
# count  5.000000e+06      5.000000e+06  ...      4.999964e+06     5.000000e+06
# mean   1.134080e+01     -7.250678e+01  ...      3.991725e+01     1.684695e+00
# std    9.820175e+00      1.280970e+01  ...      9.486767e+00     1.331854e+00
# min   -1.000000e+02     -3.426609e+03  ...     -3.488080e+03     0.000000e+00
# 25%    6.000000e+00     -7.399206e+01  ...      4.073404e+01     1.000000e+00
# 50%    8.500000e+00     -7.398181e+01  ...      4.075315e+01     1.000000e+00
# 75%    1.250000e+01     -7.396711e+01  ...      4.076811e+01     2.000000e+00
# max    1.273310e+03      3.439426e+03  ...      3.345917e+03     2.080000e+02
#
# [8 rows x 6 columns]

# %%
train = train_df[train_df.fare_amount >=0]
train = train.dropna(how='any', axis=0)
print("new size: %d" % len(train))
# Out:
# old size: 5000000
# new size: 4999753

# %%
test = pd.read_csv("/content/drive/MyDrive/258/Assignment 5/test.csv")
print("shape of test data", test.shape)
test.head()
# Out:
# shape of test data (9914, 7)
#                            key  ... passenger_count
# 0  2015-01-27 13:08:24.0000002  ...               1
# 1  2015-01-27 13:08:24.0000003  ...               1
# 2  2011-10-08 11:53:44.0000002  ...               1
# 3  2012-12-01 21:12:12.0000002  ...               1
# 4  2012-12-01 21:12:12.0000003  ...               1
#
# [5 rows x 7 columns]

# %%
def select_boundary(df, Bound):
    return (df.pickup_longitude >= Bound[0]) & (df.pickup_longitude <= Bound[1]) & (df.dropoff_longitude >= Bound[0]) & (df.dropoff_longitude <= Bound[1]) & \
           (df.pickup_latitude >= Bound[2]) & (df.pickup_latitude <= Bound[3]) &  (df.dropoff_latitude >= Bound[2]) & (df.dropoff_latitude <= Bound[3])

# %%
Bound = (-73.5, -71.8, 39.5, 40.8)
train = train[select_boundary(train, Bound)]
print('New size: %d' % len(train))
# Out:
# New size: 4893706

# %%
def prepare_time_features(df):
    df['pickup_datetime'] = df['pickup_datetime'].str.slice(0, 16)
    df['pickup_datetime'] = pd.to_datetime(df['pickup_datetime'], utc=True, format='%Y-%m-%d %H:%M')
    df['hour_of_day'] = df.pickup_datetime.dt.hour
    df['month'] = df.pickup_datetime.dt.month
    df["year"] = df.pickup_datetime.dt.year
    df["weekday"] = df.pickup_datetime.dt.weekday
    return df

# %%
def distTo(lat1, lon1, lat2, lon2):
    a = 0.5 - np.cos((lat2 - lat1) * 0.017)/2 + np.cos(lat1 * 0.017) * np.cos(lat2 * 0.017) * (1 - np.cos((lon2 - lon1) * 0.017)) / 2
    return 0.62 * 12742 * np.arcsin(np.sqrt(a))

# %%
train = prepare_time_features(train)
test = prepare_time_features(test)
train['distance_miles'] = distance(train.pickup_latitude, train.pickup_longitude,train.dropoff_latitude, train.dropoff_longitude)
test['distance_miles'] = distance(test.pickup_latitude, test.pickup_longitude, test.dropoff_latitude, test.dropoff_longitude)

# %%
# Function to add distance from near by coordinates
def transform(data):

    jfk = (-73.7781, 40.6413)
    ewr = (-74.1745, 40.6895)
    lgr = (-73.8740, 40.7769)

    data['pickup_to_jfk'] = distTo(jfk[1], jfk[0],
                                         data['pickup_latitude'], data['pickup_longitude'])
    data['dropoff_to_jfk'] = distTo(jfk[1], jfk[0],
                                           data['dropoff_latitude'], data['dropoff_longitude'])
    data['pickup_to_ewr'] = distTo(ewr[1], ewr[0], 
                                          data['pickup_latitude'], data['pickup_longitude'])
    data['dropoff_to_ewr'] = distTo(ewr[1], ewr[0],
                                           data['dropoff_latitude'], data['dropoff_longitude'])
    data['pickup_to_lgr'] = distTo(lgr[1], lgr[0],
                                          data['pickup_latitude'], data['pickup_longitude'])
    data['dropoff_to_lgr'] = distTo(lgr[1], lgr[0],
                                           data['dropoff_latitude'], data['dropoff_longitude'])
    
    return data

train = transform(train)
test = transform(test)

# %%
train[(train['distance_miles']==0)&(train['fare_amount']==0)]
# Out:
#                                  key  ...  dropoff_distance_to_lgr
# 331597   2013-08-05 06:45:54.0000005  ...                 8.777184
# 436658   2015-03-04 22:33:39.0000008  ...                 8.899057
# 689250   2015-05-27 23:10:03.0000004  ...                 6.755154
# 1662545  2010-03-13 02:39:29.0000001  ...                 8.844117
# 2214498  2010-02-03 11:44:07.0000002  ...                 8.651064
# 2329503  2015-02-19 09:43:11.0000007  ...                 4.874081
# 2581417  2015-05-07 19:12:43.0000005  ...                 2.083680
# 3070651  2015-01-25 20:54:02.0000004  ...                 5.640439
# 3252539  2015-01-14 10:15:51.0000002  ...                 3.567391
# 3712453  2010-03-29 12:47:22.0000005  ...                 6.712571
# 4191567  2010-02-22 01:02:16.0000002  ...                 5.808042
# 4307073  2010-02-13 00:30:23.0000001  ...                 5.040991
# 4377466  2015-01-16 14:56:36.0000004  ...                 3.564494
# 4819787  2015-02-18 06:47:03.0000002  ...                 3.581118
# 4851000  2010-02-10 20:18:01.0000002  ...                 7.141572
#
# [15 rows x 19 columns]

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(df_train.drop('fare_amount', axis=1),df_train['fare_amount'], test_size=0.3, random_state = 40)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (3914832, 16)
# (978708, 16)
# (3914832,)
# (978708,)

# %%
params = {
    'max_depth': 7,
    'gamma' :0,
    'eta':.03, 
    'subsample': 1,
    'colsample_bytree': 0.9, 
    'objective':'reg:linear',
    'eval_metric':'rmse',
    'silent': 0
}

# %%
def XGBmodel(X_train,X_test,y_train,y_test,params):
    matrix_train = xgb.DMatrix(X_train,label=y_train)
    matrix_test = xgb.DMatrix(X_test,label=y_test)
    model=xgb.train(params=params,
                    dtrain=matrix_train,num_boost_round=500, 
                    early_stopping_rounds=10,evals=[(matrix_test,'test')])
    return model

model = XGBmodel(X_train,X_test,y_train,y_test,params)
# Out:
# [22:35:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	test-rmse:14.125
# Will train until test-rmse hasn't improved in 10 rounds.
# [1]	test-rmse:13.7389
# [2]	test-rmse:13.3895
# [3]	test-rmse:13.0275
# [4]	test-rmse:12.6785
# [5]	test-rmse:12.3408
# [6]	test-rmse:12.0147
# [7]	test-rmse:11.6985
# [8]	test-rmse:11.3925
# [9]	test-rmse:11.0971
# [10]	test-rmse:10.8283
# [11]	test-rmse:10.5525
# [12]	test-rmse:10.2869
# [13]	test-rmse:10.028
# [14]	test-rmse:9.77928
# [15]	test-rmse:9.53946
# [16]	test-rmse:9.30771
# [17]	test-rmse:9.08474
# [18]	test-rmse:8.86859
# [19]	test-rmse:8.66108
# [20]	test-rmse:8.46012
# [21]	test-rmse:8.2664
# [22]	test-rmse:8.09036
# [23]	test-rmse:7.91179
# [24]	test-rmse:7.73926
# [25]	test-rmse:7.57358
# [26]	test-rmse:7.41307
# [27]	test-rmse:7.25895
# [28]	test-rmse:7.11081
# [29]	test-rmse:6.96905
# [30]	test-rmse:6.83142
# [31]	test-rmse:6.69941
# [32]	test-rmse:6.5729
# [33]	test-rmse:6.45134
# [34]	test-rmse:6.33484
# [35]	test-rmse:6.22878
# [36]	test-rmse:6.12134
# [37]	test-rmse:6.01789
# [38]	test-rmse:5.91912
# [39]	test-rmse:5.82416
# [40]	test-rmse:5.73329
# [41]	test-rmse:5.64661
# [42]	test-rmse:5.56336
# [43]	test-rmse:5.48392
# [44]	test-rmse:5.40818
# [45]	test-rmse:5.33541
# [46]	test-rmse:5.26666
# [47]	test-rmse:5.20053
# [48]	test-rmse:5.13719
# [49]	test-rmse:5.07715
# [50]	test-rmse:5.02004
# [51]	test-rmse:4.96515
# [52]	test-rmse:4.91294
# [53]	test-rmse:4.86283
# [54]	test-rmse:4.81524
# [55]	test-rmse:4.76984
# [56]	test-rmse:4.72713
# [57]	test-rmse:4.68552
# [58]	test-rmse:4.64666
# [59]	test-rmse:4.60905
# [60]	test-rmse:4.57362
# [61]	test-rmse:4.53943
# [62]	test-rmse:4.50692
# [63]	test-rmse:4.47562
# [64]	test-rmse:4.44726
# [65]	test-rmse:4.42007
# [66]	test-rmse:4.39362
# [67]	test-rmse:4.36816
# [68]	test-rmse:4.3442
# [69]	test-rmse:4.32154
# [70]	test-rmse:4.30035
# [71]	test-rmse:4.28051
# [72]	test-rmse:4.26089
# [73]	test-rmse:4.24236
# [74]	test-rmse:4.22459
# [75]	test-rmse:4.20773
# [76]	test-rmse:4.19169
# [77]	test-rmse:4.17597
# [78]	test-rmse:4.16153
# [79]	test-rmse:4.14771
# [80]	test-rmse:4.13474
# [81]	test-rmse:4.12169
# [82]	test-rmse:4.10919
# [83]	test-rmse:4.09735
# [84]	test-rmse:4.08611
# [85]	test-rmse:4.07513
# [86]	test-rmse:4.06497
# [87]	test-rmse:4.05535
# [88]	test-rmse:4.0464
# [89]	test-rmse:4.03819
# [90]	test-rmse:4.03029
# [91]	test-rmse:4.0226
# [92]	test-rmse:4.01471
# [93]	test-rmse:4.00709
# [94]	test-rmse:4.00054
# [95]	test-rmse:3.99421
# [96]	test-rmse:3.98755
# [97]	test-rmse:3.98177
# [98]	test-rmse:3.97611
# [99]	test-rmse:3.97038
# [100]	test-rmse:3.96452
# [101]	test-rmse:3.95942
# [102]	test-rmse:3.9548
# [103]	test-rmse:3.95003
# [104]	test-rmse:3.94492
# [105]	test-rmse:3.94067
# [106]	test-rmse:3.93662
# [107]	test-rmse:3.93243
# [108]	test-rmse:3.92874
# [109]	test-rmse:3.92458
# [110]	test-rmse:3.92124
# [111]	test-rmse:3.91812
# [112]	test-rmse:3.91455
# [113]	test-rmse:3.91087
# [114]	test-rmse:3.90796
# [115]	test-rmse:3.9047
# [116]	test-rmse:3.90225
# [117]	test-rmse:3.89992
# [118]	test-rmse:3.89766
# [119]	test-rmse:3.89487
# [120]	test-rmse:3.89234
# [121]	test-rmse:3.89016
# [122]	test-rmse:3.88767
# [123]	test-rmse:3.88517
# [124]	test-rmse:3.8828
# [125]	test-rmse:3.88042
# [126]	test-rmse:3.87826
# [127]	test-rmse:3.87661
# [128]	test-rmse:3.87468
# [129]	test-rmse:3.87246
# [130]	test-rmse:3.87003
# [131]	test-rmse:3.86765
# [132]	test-rmse:3.86607
# [133]	test-rmse:3.86318
# [134]	test-rmse:3.86192
# [135]	test-rmse:3.86063
# [136]	test-rmse:3.85902
# [137]	test-rmse:3.85775
# [138]	test-rmse:3.85684
# [139]	test-rmse:3.8536
# [140]	test-rmse:3.85053
# [141]	test-rmse:3.84929
# [142]	test-rmse:3.84804
# [143]	test-rmse:3.84521
# [144]	test-rmse:3.84406
# [145]	test-rmse:3.84287
# [146]	test-rmse:3.84183
# [147]	test-rmse:3.8408
# [148]	test-rmse:3.83934
# [149]	test-rmse:3.83851
# [150]	test-rmse:3.8375
# [151]	test-rmse:3.83661
# [152]	test-rmse:3.83597
# [153]	test-rmse:3.83531
# [154]	test-rmse:3.83309
# [155]	test-rmse:3.8321
# [156]	test-rmse:3.8314
# [157]	test-rmse:3.82926
# [158]	test-rmse:3.82853
# [159]	test-rmse:3.8279
# [160]	test-rmse:3.82716
# [161]	test-rmse:3.82573
# [162]	test-rmse:3.82509
# [163]	test-rmse:3.8243
# [164]	test-rmse:3.82259
# [165]	test-rmse:3.82216
# [166]	test-rmse:3.8216
# [167]	test-rmse:3.82078
# [168]	test-rmse:3.82028
# [169]	test-rmse:3.81945
# [170]	test-rmse:3.81887
# [171]	test-rmse:3.81779
# [172]	test-rmse:3.81729
# [173]	test-rmse:3.81624
# [174]	test-rmse:3.81378
# [175]	test-rmse:3.81324
# [176]	test-rmse:3.81275
# [177]	test-rmse:3.81191
# [178]	test-rmse:3.81153
# [179]	test-rmse:3.81098
# [180]	test-rmse:3.8095
# [181]	test-rmse:3.80869
# [182]	test-rmse:3.80822
# [183]	test-rmse:3.80769
# [184]	test-rmse:3.80721
# [185]	test-rmse:3.80537
# [186]	test-rmse:3.80479
# [187]	test-rmse:3.80398
# [188]	test-rmse:3.80347
# [189]	test-rmse:3.80294
# [190]	test-rmse:3.80224
# [191]	test-rmse:3.80185
# [192]	test-rmse:3.80011
# [193]	test-rmse:3.79969
# [194]	test-rmse:3.79925
# [195]	test-rmse:3.79811
# [196]	test-rmse:3.7976
# [197]	test-rmse:3.79705
# [198]	test-rmse:3.79657
# [199]	test-rmse:3.79601
# [200]	test-rmse:3.79553
# [201]	test-rmse:3.79399
# [202]	test-rmse:3.7934
# [203]	test-rmse:3.79309
# [204]	test-rmse:3.79277
# [205]	test-rmse:3.79209
# [206]	test-rmse:3.79101
# [207]	test-rmse:3.79062
# [208]	test-rmse:3.79035
# [209]	test-rmse:3.79012
# [210]	test-rmse:3.78827
# [211]	test-rmse:3.78782
# [212]	test-rmse:3.78752
# [213]	test-rmse:3.78658
# [214]	test-rmse:3.78573
# [215]	test-rmse:3.78531
# [216]	test-rmse:3.78401
# [217]	test-rmse:3.78366
# [218]	test-rmse:3.78338
# [219]	test-rmse:3.78137
# [220]	test-rmse:3.78059
# [221]	test-rmse:3.78033
# [222]	test-rmse:3.78005
# [223]	test-rmse:3.77977
# [224]	test-rmse:3.77954
# [225]	test-rmse:3.77926
# [226]	test-rmse:3.77872
# [227]	test-rmse:3.77863
# [228]	test-rmse:3.77815
# [229]	test-rmse:3.7765
# [230]	test-rmse:3.77622
# [231]	test-rmse:3.77477
# [232]	test-rmse:3.77457
# [233]	test-rmse:3.77371
# [234]	test-rmse:3.77351
# [235]	test-rmse:3.77311
# [236]	test-rmse:3.77278
# [237]	test-rmse:3.77244
# [238]	test-rmse:3.77215
# [239]	test-rmse:3.77181
# [240]	test-rmse:3.77114
# [241]	test-rmse:3.77061
# [242]	test-rmse:3.76981
# [243]	test-rmse:3.76955
# [244]	test-rmse:3.76934
# [245]	test-rmse:3.76909
# [246]	test-rmse:3.76884
# [247]	test-rmse:3.76856
# [248]	test-rmse:3.76787
# [249]	test-rmse:3.76724
# [250]	test-rmse:3.7671
# [251]	test-rmse:3.76674
# [252]	test-rmse:3.76655
# [253]	test-rmse:3.76524
# [254]	test-rmse:3.76425
# [255]	test-rmse:3.76398
# [256]	test-rmse:3.76362
# [257]	test-rmse:3.76352
# [258]	test-rmse:3.76319
# [259]	test-rmse:3.76221
# [260]	test-rmse:3.76121
# [261]	test-rmse:3.76042
# [262]	test-rmse:3.76003
# [263]	test-rmse:3.75996
# [264]	test-rmse:3.7597
# [265]	test-rmse:3.75934
# [266]	test-rmse:3.75914
# [267]	test-rmse:3.75871
# [268]	test-rmse:3.75835
# [269]	test-rmse:3.75756
# [270]	test-rmse:3.75724
# [271]	test-rmse:3.75665
# [272]	test-rmse:3.75639
# [273]	test-rmse:3.7556
# [274]	test-rmse:3.75528
# [275]	test-rmse:3.75525
# [276]	test-rmse:3.75475
# [277]	test-rmse:3.75455
# [278]	test-rmse:3.7537
# [279]	test-rmse:3.7536
# [280]	test-rmse:3.75349
# [281]	test-rmse:3.75336
# [282]	test-rmse:3.75299
# [283]	test-rmse:3.75223
# [284]	test-rmse:3.75193
# [285]	test-rmse:3.75162
# [286]	test-rmse:3.75155
# [287]	test-rmse:3.75091
# [288]	test-rmse:3.75058
# [289]	test-rmse:3.75018
# [290]	test-rmse:3.74972
# [291]	test-rmse:3.74953
# [292]	test-rmse:3.7492
# [293]	test-rmse:3.74819
# [294]	test-rmse:3.74758
# [295]	test-rmse:3.7472
# [296]	test-rmse:3.7467
# [297]	test-rmse:3.74641
# [298]	test-rmse:3.74629
# [299]	test-rmse:3.7459
# [300]	test-rmse:3.7454
# [301]	test-rmse:3.74533
# [302]	test-rmse:3.74451
# [303]	test-rmse:3.74424
# [304]	test-rmse:3.74416
# [305]	test-rmse:3.74356
# [306]	test-rmse:3.74348
# [307]	test-rmse:3.74338
# [308]	test-rmse:3.74285
# [309]	test-rmse:3.74256
# [310]	test-rmse:3.74208
# [311]	test-rmse:3.74181
# [312]	test-rmse:3.7417
# [313]	test-rmse:3.74161
# [314]	test-rmse:3.74138
# [315]	test-rmse:3.74128
# [316]	test-rmse:3.74114
# [317]	test-rmse:3.74086
# [318]	test-rmse:3.74083
# [319]	test-rmse:3.74019
# [320]	test-rmse:3.73979
# [321]	test-rmse:3.7393
# [322]	test-rmse:3.73928
# [323]	test-rmse:3.73898
# [324]	test-rmse:3.73898
# [325]	test-rmse:3.73859
# [326]	test-rmse:3.73845
# [327]	test-rmse:3.73812
# [328]	test-rmse:3.73808
# [329]	test-rmse:3.73762
# [330]	test-rmse:3.7374
# [331]	test-rmse:3.73715
# [332]	test-rmse:3.73685
# [333]	test-rmse:3.73623
# [334]	test-rmse:3.73591
# [335]	test-rmse:3.73589
# [336]	test-rmse:3.73574
# [337]	test-rmse:3.73555
# [338]	test-rmse:3.73502
# [339]	test-rmse:3.73469
# [340]	test-rmse:3.73447
# [341]	test-rmse:3.73342
# [342]	test-rmse:3.73338
# [343]	test-rmse:3.73311
# [344]	test-rmse:3.73283
# [345]	test-rmse:3.73267
# [346]	test-rmse:3.73171
# [347]	test-rmse:3.73141
# [348]	test-rmse:3.73125
# [349]	test-rmse:3.73114
# [350]	test-rmse:3.73099
# [351]	test-rmse:3.73066
# [352]	test-rmse:3.73042
# [353]	test-rmse:3.73002
# [354]	test-rmse:3.72978
# [355]	test-rmse:3.72908
# [356]	test-rmse:3.72887
# [357]	test-rmse:3.72813
# [358]	test-rmse:3.72792
# [359]	test-rmse:3.72772
# [360]	test-rmse:3.72719
# [361]	test-rmse:3.72715
# [362]	test-rmse:3.72669
# [363]	test-rmse:3.72632
# [364]	test-rmse:3.7259
# [365]	test-rmse:3.72577
# [366]	test-rmse:3.72517
# [367]	test-rmse:3.72492
# [368]	test-rmse:3.72477
# [369]	test-rmse:3.72398
# [370]	test-rmse:3.72373
# [371]	test-rmse:3.72312
# [372]	test-rmse:3.7231
# [373]	test-rmse:3.72298
# [374]	test-rmse:3.72214
# [375]	test-rmse:3.72205
# [376]	test-rmse:3.72178
# [377]	test-rmse:3.72147
# [378]	test-rmse:3.72123
# [379]	test-rmse:3.72049
# [380]	test-rmse:3.72039
# [381]	test-rmse:3.72016
# [382]	test-rmse:3.72003
# [383]	test-rmse:3.71987
# [384]	test-rmse:3.71968
# [385]	test-rmse:3.71939
# [386]	test-rmse:3.71935
# [387]	test-rmse:3.71921
# [388]	test-rmse:3.7185
# [389]	test-rmse:3.71828
# [390]	test-rmse:3.71816
# [391]	test-rmse:3.71773
# [392]	test-rmse:3.71752
# [393]	test-rmse:3.71745
# [394]	test-rmse:3.71726
# [395]	test-rmse:3.71684
# [396]	test-rmse:3.71673
# [397]	test-rmse:3.71666
# [398]	test-rmse:3.71664
# [399]	test-rmse:3.71631
# [400]	test-rmse:3.71602
# [401]	test-rmse:3.71601
# [402]	test-rmse:3.7156
# [403]	test-rmse:3.71534
# [404]	test-rmse:3.71521
# [405]	test-rmse:3.71507
# [406]	test-rmse:3.7145
# [407]	test-rmse:3.71415
# [408]	test-rmse:3.71403
# [409]	test-rmse:3.71399
# [410]	test-rmse:3.71399
# [411]	test-rmse:3.71382
# [412]	test-rmse:3.71323
# [413]	test-rmse:3.71262
# [414]	test-rmse:3.71251
# [415]	test-rmse:3.71229
# [416]	test-rmse:3.71217
# [417]	test-rmse:3.71174
# [418]	test-rmse:3.71165
# [419]	test-rmse:3.71155
# [420]	test-rmse:3.71116
# [421]	test-rmse:3.71084
# [422]	test-rmse:3.71051
# [423]	test-rmse:3.71032
# [424]	test-rmse:3.7102
# [425]	test-rmse:3.71002
# [426]	test-rmse:3.70969
# [427]	test-rmse:3.70933
# [428]	test-rmse:3.70905
# [429]	test-rmse:3.70891
# [430]	test-rmse:3.70873
# [431]	test-rmse:3.70868
# [432]	test-rmse:3.70845
# [433]	test-rmse:3.70818
# [434]	test-rmse:3.70787
# [435]	test-rmse:3.70751
# [436]	test-rmse:3.70731
# [437]	test-rmse:3.70702
# [438]	test-rmse:3.70639
# [439]	test-rmse:3.70621
# [440]	test-rmse:3.70613
# [441]	test-rmse:3.70596
# [442]	test-rmse:3.70573
# [443]	test-rmse:3.70552
# [444]	test-rmse:3.70535
# [445]	test-rmse:3.70525
# [446]	test-rmse:3.70505
# [447]	test-rmse:3.70481
# [448]	test-rmse:3.7047
# [449]	test-rmse:3.70457
# [450]	test-rmse:3.70421
# [451]	test-rmse:3.70386
# [452]	test-rmse:3.70383
# [453]	test-rmse:3.70362
# [454]	test-rmse:3.70351
# [455]	test-rmse:3.70324
# [456]	test-rmse:3.70316
# [457]	test-rmse:3.70298
# [458]	test-rmse:3.70288
# [459]	test-rmse:3.70275
# [460]	test-rmse:3.70242
# [461]	test-rmse:3.70199
# [462]	test-rmse:3.70183
# [463]	test-rmse:3.70176
# [464]	test-rmse:3.70147
# [465]	test-rmse:3.70135
# [466]	test-rmse:3.70123
# [467]	test-rmse:3.7011
# [468]	test-rmse:3.70105
# [469]	test-rmse:3.70091
# [470]	test-rmse:3.70075
# [471]	test-rmse:3.70073
# [472]	test-rmse:3.69991
# [473]	test-rmse:3.69958
# [474]	test-rmse:3.69943
# [475]	test-rmse:3.69925
# [476]	test-rmse:3.69908
# [477]	test-rmse:3.6988
# [478]	test-rmse:3.69861
# [479]	test-rmse:3.69804
# [480]	test-rmse:3.69754
# [481]	test-rmse:3.69742
# [482]	test-rmse:3.6973
# [483]	test-rmse:3.69711
# [484]	test-rmse:3.69671
# [485]	test-rmse:3.69668
# [486]	test-rmse:3.69644
# [487]	test-rmse:3.6963
# [488]	test-rmse:3.69617
# [489]	test-rmse:3.69609
# [490]	test-rmse:3.69599
# [491]	test-rmse:3.69584
# [492]	test-rmse:3.69559
# [493]	test-rmse:3.69546
# [494]	test-rmse:3.69537
# [495]	test-rmse:3.69532
# [496]	test-rmse:3.69494
# [497]	test-rmse:3.69461
# [498]	test-rmse:3.6943
# [499]	test-rmse:3.69426
